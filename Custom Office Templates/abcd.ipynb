# %%
import pandas as pd

# %%
dic = {"name": ["Ronaldo", "Messi"],
       "country": ["Portugal", "Argentina"],
       "Position": ["Striker","Striker"]}

# %%
dic
# Out:
# {'name': ['Ronaldo', 'Messi'],
#  'country': ['Portugal', 'Argentina'],
#  'Position': ['Striker', 'Striker']}

# %%
df = pd.Series(dic)
df
# Out:
# name             [Ronaldo, Messi]
# country     [Portugal, Argentina]
# Position       [Striker, Striker]
# dtype: object

# %%
type(df)
# Out:
# pandas.Series

# %%
df.info
# Out:
# <bound method Series.info of name             [Ronaldo, Messi]
# country     [Portugal, Argentina]
# Position       [Striker, Striker]
# dtype: object>

# %%
df.shape
# Out:
# (3,)

# %%
df1 = pd.DataFrame(dic)
df1
# Out:
#       name    country Position
# 0  Ronaldo   Portugal  Striker
# 1    Messi  Argentina  Striker

# %%
df
# Out:
# name             [Ronaldo, Messi]
# country     [Portugal, Argentina]
# Position       [Striker, Striker]
# dtype: object

# %%
a = [["joshim","actor","lottery","emotional", 70],["kancon","funny","vitamin","real", 50],["bappa raj","cheka","","classic"]]

# %%
df2 = pd.Series(a)

# %%
df2
# Out:
# 0    [joshim, actor, lottery, emotional, 70]
# 1         [kancon, funny, vitamin, real, 50]
# 2              [bappa raj, cheka, , classic]
# dtype: object

# %%
df3 = pd.DataFrame(a, columns=["Name", "rolls", "luck", "scene","year"])
df3
# Out:
#         Name  rolls     luck      scene  year
# 0     joshim  actor  lottery  emotional  70.0
# 1     kancon  funny  vitamin       real  50.0
# 2  bappa raj  cheka             classic   NaN

# %%
df3.info
# Out:
# <bound method DataFrame.info of         Name  rolls     luck      scene  year
# 0     joshim  actor  lottery  emotional  70.0
# 1     kancon  funny  vitamin       real  50.0
# 2  bappa raj  cheka             classic   NaN>

# %%
df3.isna().sum()
# Out:
# Name     0
# rolls    0
# luck     0
# scene    0
# year     1
# dtype: int64

# %%
df3.rename(columns={"Name":"name"}, inplace=True)

# %%
df3
# Out:
#         name  rolls     luck      scene  year
# 0     joshim  actor  lottery  emotional  70.0
# 1     kancon  funny  vitamin       real  50.0
# 2  bappa raj  cheka             classic   NaN

# %%
dic= {"name": ["manna","ellias"],"character": ["danger","snakeman"], "luck": ["bad","good"], "scene":["hit", "less_dramatic"], "year": [55,65]}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#      name character  luck          scene  year
# 0   manna    danger   bad            hit    55
# 1  ellias  snakeman  good  less_dramatic    65

# %%
new_df = pd.concat([df,df3],ignore_index=True)

# %%
new_df
# Out:
#         name character     luck          scene  year  rolls
# 0      manna    danger      bad            hit  55.0    NaN
# 1     ellias  snakeman     good  less_dramatic  65.0    NaN
# 2     joshim       NaN  lottery      emotional  70.0  actor
# 3     kancon       NaN  vitamin           real  50.0  funny
# 4  bappa raj       NaN                 classic   NaN  cheka

# %%
import pandas as pd

df1 = pd.DataFrame({"Name": ["Alice", "Bob"], "Age": [25, 30]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"], "Age": [35, 40]})

result = pd.concat([df1, df2], axis=0)

# %%
df1
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df2
# Out:
#       Name  Age
# 0  Charlie   35
# 1    David   40

# %%
result
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 0  Charlie   35
# 1    David   40

# %%
import pandas as pd
dic= {"cost":[10,15,25,30,35],
      "time": [150,200,155,225,250]}

# %%
df4 = DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df4 = DataFrame()
#
# NameError: name 'DataFrame' is not defined

# %%
df
# Out:
#      name character  luck          scene  year
# 0   manna    danger   bad            hit    55
# 1  ellias  snakeman  good  less_dramatic    65
