# %%
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("anagrams")

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['calculator.ipynb',
#  'class 14 and 15.py',
#  'for loop practice pml.py',
#  'for loop practice.py',
#  'hard function practice.py',
#  'my_data.csv',
#  'my_data.xlsx',
#  'pml2507 classwork.py',
#  'practice.py',
#  'practice_dataset.ipynb',
#  '__pycache__']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\ASUS\\OneDrive\\ドキュメント\\Custom Office Templates'

# %%
df.to_excel("my_data.xlsx")

# %%
df1 = pd.read_csv("my_data.csv")

# %%
df1
# Out:
#      Name  Age    City
# 0   Rahim   22   Dhaka
# 1   Karim   25  Khulna
# 2  Ayesha   21  Sylhet

# %%
df2 = pd.read_excel("my_data.xlsx")

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df.tail(3)
# Out:
#     subidr    attnr  num1  num2  num3
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
df[10:15]
# Out:
#     subidr    attnr  num1  num2  num3
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df1 = pd.read_csv(r"E:\NLP\my_data.csv")
#       2 df1.head()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
